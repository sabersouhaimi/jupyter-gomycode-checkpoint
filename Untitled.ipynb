# %%
import pandas as pd

# %%
df = pd.read_csv("dataset_titanic.csv",sep = ";")
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
q = []

for i in df["Name"]:
    title = i.split(".")[0].split(",")[1]
    q.append(title)
        
df["Status"] = q
df.drop(["PassengerId","Cabin","Name","Ticket"],inplace = True,axis = 1)

# %%
df
# Out:
#     Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked Status
# 0         No       2    male  28.0      0      0  13.0000        S     Mr
# 1         No       3    male  25.0      0      0   7.6500        S     Mr
# 2         No       3    male  20.0      0      0   7.8542        S     Mr
# 3         No       3  female  29.0      0      4  21.0750        S    Mrs
# 4         No       1    male  31.0      1      0  52.0000        S     Mr
# ..       ...     ...     ...   ...    ...    ...      ...      ...    ...
# 886      Yes       2  female  14.0      1      0  30.0708        C    Mrs
# 887       No       3    male  22.0      0      0   7.2292        C     Mr
# 888       No       3  female  30.0      0      0   8.6625        S   Miss
# 889       No       3    male   NaN      0      0   7.8958        S     Mr
# 890      Yes       2  female  19.0      0      0  26.0000        S   Miss
#
# [891 rows x 9 columns]

# %%
df.Age.fillna(df.Age.mean(),inplace = True)

# %%
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  889 non-null    object
#  1   Pclass    889 non-null    int64
#  2   Sex       889 non-null    object
#  3   Age       889 non-null    float64
#  4   SibSp     889 non-null    int64
#  5   Parch     889 non-null    int64
#  6   Fare      889 non-null    float64
#  7   Embarked  889 non-null    object
#  8   Status    889 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 69.5+ KB

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
to_label = ["Survived","Sex","Embarked","Status"]
for label in to_label:
    df[label] = lb.fit_transform(df[label])

# %%
from sklearn.model_selection import train_test_split
x = df.drop('Survived',axis = 1)
y = df['Survived']
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size= 0.20)

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree,export_graphviz ,export_text,plot_tree
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
model = DecisionTreeClassifier()
model.fit(xtrain,ytrain)
yprediction = model.predict(xtest)
print(accuracy_score(ytest,yprediction))
# Out:
# 0.797752808988764

# %%
text_representation = export_text(model)
print(text_representation)
# Out:
# |--- feature_1 <= 0.50
# |   |--- feature_0 <= 2.50
# |   |   |--- feature_5 <= 29.39
# |   |   |   |--- feature_5 <= 28.23
# |   |   |   |   |--- feature_2 <= 56.00
# |   |   |   |   |   |--- feature_2 <= 23.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_2 >  23.50
# |   |   |   |   |   |   |--- feature_2 <= 27.50
# |   |   |   |   |   |   |   |--- feature_2 <= 25.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 13.75
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_5 >  13.75
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  25.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 10.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_7 >  10.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  27.50
# ...

# %% [markdown]
# Model 1 accuracy:   0.8258426966292135
# Model 2 accuracy:  0.7752808988764045

# %%
model2 = DecisionTreeClassifier(splitter = "random",max_features = "sqrt")
model2.fit(xtrain,ytrain)
yprediction = model2.predict(xtest)
print(accuracy_score(ytest,yprediction))
# Out:
# 0.7696629213483146

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()
rfc.fit(xtrain,ytrain)
y_pred = rfc.predict(xtest)
print(accuracy_score(ytest,y_pred))
# Out:
# 0.8314606741573034

# %%
rfc = RandomForestClassifier(n_estimators=5)
rfc.fit(xtrain,ytrain)
y_pred = rfc.predict(xtest)
print(accuracy_score(ytest,y_pred))
# Out:
# 0.8033707865168539

# %% [markdown]
# before changing n_estimator:0.8314606741573034
#
#
# after ***** :    0.8202247191011236
